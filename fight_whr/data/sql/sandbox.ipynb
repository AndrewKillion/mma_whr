# %%
import pandas as pd
import os

print(os.getcwd())
# Out:
# /Users/andrewkillion/Desktop/mma_whr/mma_whr/fight_whr

# %%
dat = pd.read_parquet('../data/local/ufc_fights.parquet')

dat
# Out:
#              fighter_a         fighter_b        date winner  \
# 0         Royce Gracie     Art Jimmerson  1993-11-12      A
# 1         Royce Gracie    Gerard Gordeau  1993-11-12      A
# 2       Gerard Gordeau        Teila Tuli  1993-11-12      A
# 3        Jason DeLucia     Trent Jenkins  1993-11-12      A
# 4         Royce Gracie      Ken Shamrock  1993-11-12      A
# ...                ...               ...         ...    ...
# 10934  Nicolle Caliari     Shauna Bannon  2026-05-16      A
# 10935    Daniel Santos        Dooho Choi  2026-05-16      B
# 10936     Arnold Allen  Melquizael Costa  2026-05-16      A
# 10937   Alice Ardelean     Polyana Viana  2026-05-16      A
# 10938    Benardo Sopaj      Timmy Cuamba  2026-05-16      A
#
#                      method             weightclass
# 0                Submission             OPEN WEIGHT
# 1                Submission  UFC 1 TOURNAMENT TITLE
# 2                    KO/TKO             OPEN WEIGHT
# ...
