# %%
import pandas as pd
import os

print(os.getcwd())

df = pd.read_parquet("../data/local/whr_rankings.parquet")
df.head(20)
df.sort_values("current_score", ascending=False)

df['current_weightclass'].unique()
# Out:
# /Users/andrewkillion/Desktop/mma_whr/mma_whr/scripts
# array(['UFC HEAVYWEIGHT TITLE', 'HEAVYWEIGHT', 'UFC MIDDLEWEIGHT TITLE',
#        'UFC INTERIM HEAVYWEIGHT TITLE', 'WELTERWEIGHT',
#        "WOMEN'S FEATHERWEIGHT", 'UFC LIGHT HEAVYWEIGHT TITLE',
#        'UFC WELTERWEIGHT TITLE', 'MIDDLEWEIGHT', 'UFC LIGHTWEIGHT TITLE',
#        'FEATHERWEIGHT', 'UFC FEATHERWEIGHT TITLE', 'CATCH WEIGHT',
#        'LIGHT HEAVYWEIGHT', 'BANTAMWEIGHT', "WOMEN'S BANTAMWEIGHT",
#        'LIGHTWEIGHT', "STRIKEFORCE WOMEN'S 145 LBS. TITLE",
#        'DREAM LIGHTWEIGHT TITLE', 'UFC BANTAMWEIGHT TITLE',
#        'UFC INTERIM LIGHTWEIGHT TITLE', 'OPEN WEIGHT',
#        'DREAM LIGHT HEAVYWEIGHT TITLE', 'WEC LIGHT HEAVYWEIGHT TITLE',
#        'UFC FLYWEIGHT TITLE', 'FLYWEIGHT', 'SUPER HEAVYWEIGHT',
#        "WOMEN'S STRAWWEIGHT", 'DREAM 2009 SUPER HULK TOURNAMENT TITLE',
#        'ULTIMATE FIGHTER 25 WELTERWEIGHT TOURNAMENT TITLE',
#        'ULTIMATE JAPAN HEAVYWEIGHT TOURNAMENT TITLE',
# ...
